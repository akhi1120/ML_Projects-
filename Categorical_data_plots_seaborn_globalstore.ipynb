# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd 
import xlrd

# %% [markdown]
# # Load dataset

# %%
# df = pd.read_csv("C:\\Users\\akhil\\Downloads\\Global-Superstore.csv")

# %%
 xls = pd.ExcelFile("C:\\Users\\akhil\\Downloads\\Gen-AI_Internship\\Global-Superstore (1).xlsx")

# %%
df1=pd.read_excel(xls)

# %%
df1.shape
# Out:
# (51290, 24)

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
import seaborn as sns

# %%
df=df1.loc[0:1000,:]

# %% [markdown]
# # visualizations

# %%
sns.catplot(x='Sales',y='Discount',data=df,palette='rainbow',alpha=1)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\1961837228.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sales',y='Discount',data=df,palette='rainbow',alpha=1)

# %%
sns.catplot(x='Sales',y='Discount',col='Category',data=df,palette='rainbow',alpha=1)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\2911836161.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sales',y='Discount',col='Category',data=df,palette='rainbow',alpha=1)

# %%
sns.lineplot(x='Discount',y='Sales',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Sales'>

# %%
sns.lineplot(x='Discount',y='Profit',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(50, 10))
sns.barplot(x='Sales',y='Profit',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.catplot(x='Category',y='Profit',kind="box",data=df,palette='rainbow')
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\2054613948.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Category',y='Profit',kind="box",data=df,palette='rainbow')

# %%
sns.catplot(x='Sub-Category',y='Sales',kind="violin",data=df,palette='rainbow')
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\3202687172.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sub-Category',y='Sales',kind="violin",data=df,palette='rainbow')

# %%
sns.catplot(x='Ship Mode',kind="count",data=df,palette='rainbow')
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\2139815671.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Ship Mode',kind="count",data=df,palette='rainbow')

# %%
sns.catplot(x='Ship Mode',y='Sales',kind="point",data=df)

# %%
sns.catplot(x='Category',y='Profit',kind="swarm",data=df,palette='viridis')
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\4203771847.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Category',y='Profit',kind="swarm",data=df,palette='viridis')
# c:\Users\akhil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 59.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\akhil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 52.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.barplot(x='Sales',y='Discount',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>

# %%
sns.barplot(x='Sales',y='Profit',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(25,20))
g=sns.barplot(x='Discount',y='Profit',hue='Category',data=df)

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Discount',y='Profit',hue='Market',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
df2=df.drop(['Row ID','Order ID'],axis=1)

# %%
sns.pairplot(data=df2)

# %%
sns.pairplot(data=df2,hue='Category',palette='rainbow')

# %%
plt.figure(figsize=(25,20))
sns.lineplot(x='Sales',y='Profit',hue='Country',data=df2)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(25,20))
sns.lineplot(x='Sales',y='Discount',hue='Country',data=df2)
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>

# %%
sns.lmplot(x='Discount',y='Sales',data=df2,  fit_reg=False)

# %%
sns.lmplot(x='Discount',y='Profit',data=df2,  fit_reg=False)

# %%
import numpy as np
df3=df1[['Sales','Profit','Discount']]

# %%
plt.figure(figsize=(50, 30))
sns.heatmap(data=df3,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Sales", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Discount", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
colors = ['purple', 'pink', 'green', 'orange','blue','brown']

sns.countplot(x='Market',data=df, alpha=1,palette=colors)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\526882045.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Market',data=df, alpha=1,palette=colors)
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\526882045.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Market',data=df, alpha=1,palette=colors)
# <Axes: xlabel='Market', ylabel='count'>

# %%
colors = ['purple', 'pink', 'green', 'orange','blue','brown']

sns.barplot(x='Market',y='Profit',data=df,palette=colors)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\1760792538.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Market',y='Profit',data=df,palette=colors)
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\1760792538.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Market',y='Profit',data=df,palette=colors)
# <Axes: xlabel='Market', ylabel='Profit'>

# %%
colors = ['purple', 'pink', 'green', 'orange','blue','brown']

sns.boxplot(x='Market',y='Profit',data=df,palette=colors)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\57500541.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Market',y='Profit',data=df,palette=colors)
# C:\Users\akhil\AppData\Local\Temp\ipykernel_18892\57500541.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x='Market',y='Profit',data=df,palette=colors)
# <Axes: xlabel='Market', ylabel='Profit'>

# %%
df4=df[["Sales","Profit","Discount","Shipping Cost","Quantity"]]

# %%
df4_corr = df4.corr()

# %%
sns.heatmap(data=df4_corr,cmap="rainbow",annot=True)
# Out:
# <Axes: >
